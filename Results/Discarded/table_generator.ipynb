# %%
import pandas as pd

df=pd.read_csv("results.csv")
df.rename(columns={'recall1': 'Recall@1',
                   'recall3': 'Recall@3',
                   'recall5':"Recall@5",
                   'recall10':"Recall@10",
                   "mean_rank":"Mean Rank",
                   "norm_sim":"MNS(Mean Normalised Similarity)",
                   "margin":"MD(Margin of Discrimination)",
                   "avg_confidence":"Mean Confidence",
                   'mrr': "Mean Reciprocal Rank (MRR)"
                  },
          inplace=True, errors='raise')
df
# Out:
#   Similarity Method Melody Extractor    Processed  Recall@1  Recall@3  \
# 0              Text         Modified  Unprocessed  1.000000  1.000000
# 1              Text          Skyline  Unprocessed  1.000000  1.000000
# 2              Time         Modified  Unprocessed  0.947368  0.973684
# 3              Time          Skyline  Unprocessed  0.842105  0.947368
# 4              Text          Skyline    Processed  0.526316  0.657895
# 5              Text         Modified    Processed  0.473684  0.605263
# 6              Time         Modified    Processed  0.052632  0.078947
# 7              Time          Skyline    Processed  0.052632  0.157895
#
#    Recall@5  Recall@10   Mean Rank  MNS(Mean Normalised Similarity)  \
# 0  1.000000   1.000000    1.000000                         1.000000
# 1  1.000000   1.000000    1.000000                         1.000000
# 2  0.973684   1.000000    1.184211                         0.999301
# ...

# %%
recall=df[["Similarity Method","Melody Extractor","Processed","Recall@1","Recall@3","Recall@5","Recall@10"]]
recall.to_csv("recall.csv",index=False)
recall
# Out:
#   Similarity Method Melody Extractor    Processed  Recall@1  Recall@3  \
# 0              Text         Modified  Unprocessed  1.000000  1.000000
# 1              Text          Skyline  Unprocessed  1.000000  1.000000
# 2              Time         Modified  Unprocessed  0.947368  0.973684
# 3              Time          Skyline  Unprocessed  0.842105  0.947368
# 4              Text          Skyline    Processed  0.526316  0.657895
# 5              Text         Modified    Processed  0.473684  0.605263
# 6              Time         Modified    Processed  0.052632  0.078947
# 7              Time          Skyline    Processed  0.052632  0.157895
#
#    Recall@5  Recall@10
# 0  1.000000   1.000000
# 1  1.000000   1.000000
# 2  0.973684   1.000000
# 3  0.973684   0.973684
# 4  0.684211   0.684211
# 5  0.631579   0.657895
# 6  0.157895   0.236842
# 7  0.210526   0.236842

# %%
MRR = df[["Similarity Method", "Melody Extractor", "Processed", "Mean Reciprocal Rank (MRR)"]]
MRR.to_csv("mrr.csv", index=False)
MRR
# Out:
#   Similarity Method Melody Extractor    Processed  Mean Reciprocal Rank (MRR)
# 0              Text         Modified  Unprocessed                    1.000000
# 1              Text          Skyline  Unprocessed                    1.000000
# 2              Time         Modified  Unprocessed                    0.964286
# 3              Time          Skyline  Unprocessed                    0.900070
# 4              Text          Skyline    Processed                    0.592642
# 5              Text         Modified    Processed                    0.542669
# 6              Time         Modified    Processed                    0.102821
# 7              Time          Skyline    Processed                    0.133539

# %%
MR=df[["Similarity Method","Melody Extractor","Processed","Mean Rank"]]
MR.to_csv("mean_rank.csv",index=False)
MR
# Out:
#   Similarity Method Melody Extractor    Processed   Mean Rank
# 0              Text         Modified  Unprocessed    1.000000
# 1              Text          Skyline  Unprocessed    1.000000
# 2              Time         Modified  Unprocessed    1.184211
# 3              Time          Skyline  Unprocessed   11.078947
# 4              Text          Skyline    Processed  146.842105
# 5              Text         Modified    Processed  194.842105
# 6              Time         Modified    Processed  363.605263
# 7              Time          Skyline    Processed  329.026316

# %%
MNS=df[["Similarity Method","Melody Extractor","Processed","MNS(Mean Normalised Similarity)"]]
MNS.to_csv("mns.csv",index=False)
MNS
# Out:
#   Similarity Method Melody Extractor    Processed  \
# 0              Text         Modified  Unprocessed
# 1              Text          Skyline  Unprocessed
# 2              Time         Modified  Unprocessed
# 3              Time          Skyline  Unprocessed
# 4              Text          Skyline    Processed
# 5              Text         Modified    Processed
# 6              Time         Modified    Processed
# 7              Time          Skyline    Processed
#
#    MNS(Mean Normalised Similarity)
# 0                         1.000000
# 1                         1.000000
# 2                         0.999301
# 3                         0.986434
# 4                         0.880409
# 5                         0.847895
# 6                         0.721013
# 7                         0.753566

# %%
MDS=df[["Similarity Method","Melody Extractor","Processed","Recall@1","MD(Margin of Discrimination)"]]
MDS.to_csv("mds.csv",index=False)
MDS
# Out:
#   Similarity Method Melody Extractor    Processed  Recall@1  \
# 0              Text         Modified  Unprocessed  1.000000
# 1              Text          Skyline  Unprocessed  1.000000
# 2              Time         Modified  Unprocessed  0.947368
# 3              Time          Skyline  Unprocessed  0.842105
# 4              Text          Skyline    Processed  0.526316
# 5              Text         Modified    Processed  0.473684
# 6              Time         Modified    Processed  0.052632
# 7              Time          Skyline    Processed  0.052632
#
#    MD(Margin of Discrimination)
# 0                      0.285800
# 1                      0.290936
# 2                      0.191037
# 3                      0.202716
# 4                      0.123667
# 5                      0.100749
# 6                      0.000374
# 7                      0.000266

# %%
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set_theme()

# %%
recall
# Out:
#   Similarity Method Melody Extractor    Processed  Recall@1  Recall@3  \
# 0              Text         Modified  Unprocessed  1.000000  1.000000
# 1              Text          Skyline  Unprocessed  1.000000  1.000000
# 2              Time         Modified  Unprocessed  0.947368  0.973684
# 3              Time          Skyline  Unprocessed  0.842105  0.947368
# 4              Text          Skyline    Processed  0.526316  0.657895
# 5              Text         Modified    Processed  0.473684  0.605263
# 6              Time         Modified    Processed  0.052632  0.078947
# 7              Time          Skyline    Processed  0.052632  0.157895
#
#    Recall@5  Recall@10
# 0  1.000000   1.000000
# 1  1.000000   1.000000
# 2  0.973684   1.000000
# 3  0.973684   0.973684
# 4  0.684211   0.684211
# 5  0.631579   0.657895
# 6  0.157895   0.236842
# 7  0.210526   0.236842

# %%
sim_list = list(recall['Similarity Method'][:4])
melody_list = list(recall['Melody Extractor'][:4])
recall_1 = list(recall['Recall@1'][:4])
recall_3 = list(recall['Recall@3'][:4])
recall_5 = list(recall['Recall@5'][:4])
recall_10 = list(recall['Recall@10'][:4])

# %%
labels = []
for i in range(len(sim_list)):
    labels.append(sim_list[i] + '-' + melody_list[i])

# %%
rec_list = [recall_1, recall_3, recall_5, recall_10]
for i,p in enumerate([1,3,5,10]):
    barplot =  plt.bar(labels, rec_list[i], label=f'Recall@{p}',width=0.4)
    barplot[0].set_color('red')
    barplot[1].set_color('magenta')
    barplot[2].set_color('blue')
    barplot[3].set_color('green')
    plt.xlabel('Method')
    plt.ylabel(f'Recall@{p}')
    plt.title(f'Recall@{p}')
    plt.savefig(f'recall_{p}.png',dpi=1200)

# %%
allscores = []
for i in range(4):
    allscores.append([recall_1[i], recall_3[i], recall_5[i], recall_10[i]])

# %%
plt.plot([1,3,5,10],allscores[0],label = 'Text-Modified',color='red')
plt.plot([1,3,5,10],allscores[1],label = 'Text-Skyline',color='red')
plt.plot([1,3,5,10],allscores[2],label = 'Time-Modified',color = 'blue')
plt.plot([1,3,5,10],allscores[3],label = 'Time-Skyline',color='green')
plt.xlabel('Recall@k',fontsize=14)
plt.ylabel('k',fontsize=14)
plt.title('Recall@k',fontsize=14)
plt.legend()
plt.savefig('recall_all.png',dpi=1200)

# %%
import json
with open('timeres.json') as f:
    timeres = json.load(f)

# %%
for key, value in timeres.items():
    timeres[key] = value/40

# %%
# convert timeres to dataframe
timeres_df = pd.DataFrame.from_dict(timeres, orient='index')
# drop those keys which contain 'processed'
timeres_df = timeres_df.drop(timeres_df[timeres_df.index.str.contains('processed')].index)

# %%
timeres_df.rename(columns={0:'Time'},inplace=True)

# %%
# sort by time
timeres_df = timeres_df.sort_values(by='Time')

# %%
timeres_df.to_csv('timeres.csv',index=False)
