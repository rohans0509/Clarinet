# %%
import miditoolkit
import os
import mido

# %%
#midi_obj = miditoolkit.midi.parser.MidiFile()
mid = mido.MidiFile(r"Data\Midi\2018\MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--3.midi")

# %%
for i, track in enumerate(mid.tracks):
    print('Track {}: {}'.format(i, track.name))
    for msg in track:
        print(msg)
        break
# Out:
# Track 0:
# MetaMessage('set_tempo', tempo=500000, time=0)
# Track 1: 1 to 3
# MetaMessage('track_name', name='1 to 3', time=0)

# %%
from Clarinet.visualiser import visualise
visualise("/Users/rohansharma/Desktop/IIT DELHI/Academics/Sem 5/COL764/Clarinet/Data/Midi/Consolidated/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_05_Track05_wav.midi")
visualise("/Users/rohansharma/Desktop/IIT DELHI/Academics/Sem 5/COL764/Clarinet/Data/Melody/Consolidated/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_05_Track05_wav_melody.mid")
visualise("/Users/rohansharma/Desktop/IIT DELHI/Academics/Sem 5/COL764/Clarinet/Data/Melody/Consolidated_modified/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_05_Track05_wav_melody.mid")
