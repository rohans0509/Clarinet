# %%
import json
import os
import miditoolkit

# %%
data_dir = "C:/Users/Kshitij Alwadhi/Documents/GitHub/Clarinet/Data/Json/2018_clipped/"+'melody.json'
queries = "C:/Users/Kshitij Alwadhi/Documents/GitHub/Clarinet/Data/Json/2018_queries/"+'melody.json'

# %%
def getConversion(path):
    fname_to_conv = {}
    files = os.listdir(path)
    for fname in files:
        mid_in = miditoolkit.midi.parser.MidiFile(os.path.join(path, fname))
        fname_to_conv[fname] = mid_in.get_tick_to_time_mapping()[1]
    return fname_to_conv


fname_to_convData = getConversion(r"C:/Users/Kshitij Alwadhi/Documents/GitHub/Clarinet/Data/Melody/2018_clipped/")
fname_to_convQuery = getConversion(r"C:/Users/Kshitij Alwadhi/Documents/GitHub/Clarinet/Data/Melody/2018_queries/")

# %%
factor = 768
#factor = 1000

# %%
def splitNotes(notes):
    new_notes = []
    for note in notes:
        start = note[1]/1000.
        end = note[2]/1000.
        startSec = int(start)
        endSec = int(end)

        if startSec == endSec:
            new_notes.append(note)
        else:
            new_notes.append([note[0], note[1], (startSec+1)*1000, note[3]])
            for i in range(startSec+1, endSec-1):
                new_notes.append([note[0], int(i*1000), int(i+1)*1000, note[3]])
            new_notes.append([note[0], int(endSec*1000), note[2], note[3]])
    return new_notes

# %%
def getStrides(notes, size):
    notes = sorted(notes, key=lambda x: x[1])
    chunks = []
    for _ in range(len(notes)+1000):
        chunks.append([])

    curT = 0
    nextidx = 0
    flag = False

    i = 0
    while(i < len(notes)):
        st = notes[i][1]
        maxT = curT + size
        if st >= maxT:
            curT += 1000
            i = nextidx
            flag = False
            continue

        if st % 1000 == 0 and flag == False and st != curT:
            nextidx = i
            flag = True

        pos = int(curT/1000)
        chunks[pos].append(notes[i])
        i += 1
    ans = []
    for c in chunks:
        if len(c) > 0:
            ans.append(c)
    return ans

# %%
def splitNotes(notes):
    new_notes = []
    for note in notes:
        start = note[1]/factor
        end = note[2]/factor
        startSec = int(start)
        endSec = int(end)

        if startSec == endSec:
            new_notes.append(note)
        else:
            new_notes.append([note[0], note[1], (startSec+1)*factor, note[3]])
            for i in range(startSec+1, endSec-1):
                new_notes.append([note[0], int(i*factor), int(i+1)*factor, note[3]])
            new_notes.append([note[0], int(endSec*factor), note[2], note[3]])
    return new_notes

# %%
def getStrides(notes, size):
    notes = sorted(notes, key=lambda x: x[1])
    chunks = []
    for _ in range(len(notes)+factor):
        chunks.append([])

    curT = 0
    nextidx = 0
    flag = False

    i = 0
    while(i < len(notes)):
        st = notes[i][1]
        maxT = curT + size
        if st >= maxT:
            curT += factor
            i = nextidx
            flag = False
            continue

        if st % factor == 0 and flag == False and st != curT:
            nextidx = i
            flag = True

        pos = int(curT/factor)
        chunks[pos].append(notes[i])
        i += 1
    ans = []
    for c in chunks:
        if len(c) > 0:
            ans.append(c)
    return ans

# %%
with open(data_dir, 'r') as f:
    fname_to_notes = json.load(f)

# %%
# a function which calculates the edit distance between two strings
def edit_distance(s1, s2):
    m = len(s1)
    n = len(s2)
    dp = [[0 for x in range(n+1)] for x in range(m+1)]
    for i in range(m+1):
        for j in range(n+1):
            if i == 0:
                dp[i][j] = j
            elif j == 0:
                dp[i][j] = i
            elif s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = 1 + min(dp[i][j-1], dp[i-1][j], dp[i-1][j-1])
    return dp[m][n]


# a function which calculates the similarity between two strings
def similarity(s1, s2):
    return 1 - edit_distance(s1, s2) / max(len(s1), len(s2))
    #return edit_distance(s1, s2)


midiEt_to_note = {
    12: "C",
    13: "C#",
    14: "D",
    15: "D#",
    16: "E",
    17: "F",
    18: "F#",
    19: "G",
    20: "G#",
    21: "A",
    22: "A#",
    23: "B"
}


# a function which converts a sequence of midiEt to a sequence of notes
def midiEt_to_note_sequence(midiEt_sequence):
    note_sequence = []
    for midiEt in midiEt_sequence:
        num = midiEt % 12
        note_sequence.append(midiEt_to_note[num + 12])
    return "".join(note_sequence)

# %%
def compute_similarities(query):
    fname_to_similarity = {}
    for fname in tqdm(fname_to_notes):
        sim = 0
        notes = fname_to_notes[fname]
        notes = splitNotes(notes)
        #strides = getStrides(notes, 5000)
        strides = getStrides(notes, 5*factor)

        for stride in strides:
            stride_notes = [note[0] for note in stride]
            note_sequence = midiEt_to_note_sequence(stride_notes)
            sim = max(sim, similarity(query, note_sequence))
        fname_to_similarity[fname] = sim
    return fname_to_similarity

# %%
from tqdm import tqdm

# %%
with open(queries, 'r') as f:
    queries_to_notes = json.load(f)

# %%
qname = "MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--4_query_melody.mid"

# %%
qnotes = queries_to_notes[qname]

# %%
qnotes = [note[0] for note in qnotes]
query = midiEt_to_note_sequence(qnotes)

# %%
fname_to_similarity = compute_similarities(query)
# Out:
# 100%|██████████| 93/93 [00:00<00:00, 134.25it/s]

# %%
dict(sorted(fname_to_similarity.items(), key=lambda item: item[1],reverse=True))
# Out:
# {'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--4_melody.mid': 0.7619047619047619,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--1_melody.mid': 0.75,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--3_melody.mid': 0.7058823529411764,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--2_melody.mid': 0.7,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--4_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--3_melody.mid': 0.6,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital20_MID--AUDIO_20_R1_2018_wav--4_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--1_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1_melody.mid': 0.5454545454545454,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--2_melody.mid': 0.5294117647058824,
#  'MIDI-Unprocessed_Schubert7-9_MID--AUDIO_11_R2_2018_wav_melody.mid': 0.5263157894736843,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--2_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--4_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital20_MID--AUDIO_20_R1_2018_wav--3_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--2_melody.mid': 0.5,
#  'MIDI-Unprocessed_Schubert1-3_MID--AUDIO_07_R2_2018_wav_melody.mid': 0.5,
#  'MIDI-Unprocessed_Schubert7-9_MID--AUDIO_16_R2_2018_wav_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--2_melody.mid': 0.4736842105263158,
#  'MIDI-Unprocessed_Schubert1-3_MID--AUDIO_05_R2_2018_wav_melody.mid': 0.4642857142857143,
#  'MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--2_melody.mid': 0.4444444444444444,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--2_melody.mid': 0.4444444444444444,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--3_melody.mid': 0.43999999999999995,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--2_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--5_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--1_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--3_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_melody.mid': 0.4347826086956522,
#  'MIDI-Unprocessed_Schubert4-6_MID--AUDIO_09_R2_2018_wav_melody.mid': 0.4285714285714286,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--2_melody.mid': 0.42307692307692313,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--3_melody.mid': 0.42105263157894735,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--2_melody.mid': 0.41666666666666663,
#  'MIDI-Unprocessed_Chamber4_MID--AUDIO_11_R3_2018_wav--1_melody.mid': 0.40909090909090906,
#  'MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1_melody.mid': 0.4,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--3_melody.mid': 0.3928571428571429,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--1_melody.mid': 0.38888888888888884,
#  'MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--2_melody.mid': 0.3793103448275862,
#  'MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--1_melody.mid': 0.36363636363636365,
#  'MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--2_melody.mid': 0.36363636363636365,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--1_melody.mid': 0.36363636363636365,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--2_melody.mid': 0.36363636363636365,
#  'MIDI-Unprocessed_Schubert4-6_MID--AUDIO_08_R2_2018_wav_melody.mid': 0.36,
#  'MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_melody.mid': 0.36,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--1_melody.mid': 0.3589743589743589,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--5_melody.mid': 0.3529411764705882,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--3_melody.mid': 0.3529411764705882,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--5_melody.mid': 0.3529411764705882,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--1_melody.mid': 0.35,
#  'MIDI-Unprocessed_Schubert10-12_MID--AUDIO_17_R2_2018_wav_melody.mid': 0.35,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--3_melody.mid': 0.34782608695652173,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--1_melody.mid': 0.34375,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--4_melody.mid': 0.3414634146341463,
#  'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_melody.mid': 0.33333333333333337,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--5_melody.mid': 0.33333333333333337,
#  'MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--1_melody.mid': 0.33333333333333337,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--3_melody.mid': 0.33333333333333337,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--4_melody.mid': 0.33333333333333337,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--1_melody.mid': 0.32258064516129037,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--1_melody.mid': 0.31999999999999995,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--4_melody.mid': 0.31818181818181823,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--5_melody.mid': 0.3157894736842105,
#  'MIDI-Unprocessed_Schubert7-9_MID--AUDIO_15_R2_2018_wav_melody.mid': 0.3157894736842105,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--4_melody.mid': 0.3142857142857143,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--4_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--1_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Schubert10-12_MID--AUDIO_20_R2_2018_wav_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--2_melody.mid': 0.30612244897959184,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--4_melody.mid': 0.30434782608695654,
#  'MIDI-Unprocessed_Schubert10-12_MID--AUDIO_18_R2_2018_wav_melody.mid': 0.30434782608695654,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--2_melody.mid': 0.29729729729729726,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--1_melody.mid': 0.28205128205128205,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--3_melody.mid': 0.28,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1_melody.mid': 0.28,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--1_melody.mid': 0.276595744680851,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--6_melody.mid': 0.2727272727272727,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--5_melody.mid': 0.2666666666666667,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--3_melody.mid': 0.2647058823529411,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_melody.mid': 0.2647058823529411,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--2_melody.mid': 0.25,
#  'MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3_melody.mid': 0.25,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--2_melody.mid': 0.25,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--3_melody.mid': 0.24590163934426235,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--6_melody.mid': 0.24489795918367352,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--2_melody.mid': 0.2222222222222222,
#  'MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--3_melody.mid': 0.22058823529411764,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--3_melody.mid': 0.21666666666666667,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--2_melody.mid': 0.20967741935483875,
#  'MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--2_melody.mid': 0.189873417721519,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--1_melody.mid': 0.1875}

# %%
def distance(s1:str,s2:str):
    m = len(s1)
    n = len(s2)
    dp = [[0 for x in range(n+1)] for x in range(m+1)]
    for i in range(m+1):
        for j in range(n+1):
            if i == 0:
                dp[i][j] = j
            elif j == 0:
                dp[i][j] = i
            elif s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = 1 + min(dp[i][j-1], dp[i-1][j], dp[i-1][j-1])
    return dp[m][n]


def similarityv2(query:str,data:str):
    query_len=len(query)
    data_len=len(data)

    s1=query

    score=float("inf")

    start=-1
    end=-1

    while end<data_len:
        start=start+1
        end=min(start+query_len,data_len)

        s2=data[start:end]
        

        edit_distance=distance(s1,s2)
        if edit_distance<score:
            score=edit_distance

    sim=1-score/query_len
    return(sim)

# %%
def compute_similaritiesv2(query):
    fname_to_similarity = {}
    for fname in fname_to_notes:
        sim = 0
        notes = fname_to_notes[fname]
        nn = []
        for n in notes:
            nn.append(n[0])
        note_sequence = midiEt_to_note_sequence(nn)
        sim = max(sim, similarityv2(query, note_sequence))
        fname_to_similarity[fname] = sim
    return fname_to_similarity

# %%
fname_to_similarity2 = compute_similaritiesv2(query)

# %%
fname_to_similarity2 = dict(sorted(fname_to_similarity2.items(), key=lambda item: item[1],reverse=True))

# %%
fname_to_similarity2
# Out:
# {'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--4_melody.mid': 1.0,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--2_melody.mid': 0.8125,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--2_melody.mid': 0.6875,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--2_melody.mid': 0.6875,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--4_melody.mid': 0.6875,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--2_melody.mid': 0.6875,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--3_melody.mid': 0.6875,
#  'MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--2_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--3_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--2_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--3_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--2_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--4_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital20_MID--AUDIO_20_R1_2018_wav--4_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--1_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--1_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--2_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--2_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--5_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--2_melody.mid': 0.625,
#  'MIDI-Unprocessed_Schubert1-3_MID--AUDIO_05_R2_2018_wav_melody.mid': 0.625,
#  'MIDI-Unprocessed_Schubert7-9_MID--AUDIO_16_R2_2018_wav_melody.mid': 0.625,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--1_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--4_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--1_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--1_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--2_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital20_MID--AUDIO_20_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--1_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--2_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--3_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Schubert10-12_MID--AUDIO_20_R2_2018_wav_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Schubert4-6_MID--AUDIO_08_R2_2018_wav_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Schubert7-9_MID--AUDIO_11_R2_2018_wav_melody.mid': 0.5625,
#  'MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1_melody.mid': 0.5,
#  'MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--2_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--5_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--3_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--1_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--6_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--2_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--2_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--3_melody.mid': 0.5,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--1_melody.mid': 0.5,
#  'MIDI-Unprocessed_Schubert1-3_MID--AUDIO_07_R2_2018_wav_melody.mid': 0.5,
#  'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Chamber4_MID--AUDIO_11_R3_2018_wav--1_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--2_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--3_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--2_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--1_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--1_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--4_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--5_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--3_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--3_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--5_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--6_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav_melody.mid': 0.4375,
#  'MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--2_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--1_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--1_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--1_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--4_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--5_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--1_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--2_melody.mid': 0.375,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--5_melody.mid': 0.375,
#  'MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav_melody.mid': 0.375,
#  'MIDI-Unprocessed_Schubert10-12_MID--AUDIO_17_R2_2018_wav_melody.mid': 0.375,
#  'MIDI-Unprocessed_Schubert10-12_MID--AUDIO_18_R2_2018_wav_melody.mid': 0.375,
#  'MIDI-Unprocessed_Schubert4-6_MID--AUDIO_09_R2_2018_wav_melody.mid': 0.375,
#  'MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--4_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--2_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--3_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--4_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--4_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--3_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Schubert7-9_MID--AUDIO_15_R2_2018_wav_melody.mid': 0.3125,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--1_melody.mid': 0.25,
#  'MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3_melody.mid': 0.1875,
#  'MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--1_melody.mid': 0.1875}
