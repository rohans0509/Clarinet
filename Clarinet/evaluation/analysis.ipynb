# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_theme()

# %%
results = "results.json"
df = pd.read_json(results)
df = df.transpose()

# edit row names in df
df.index = df.index.map(lambda x: x.replace("res_", ""))
df.index = df.index.map(lambda x: x.replace(".json", ""))
df.index = df.index.map(lambda x: x.replace("text", "Text"))
df.index = df.index.map(lambda x: x.replace("_", "-"))
df = df.sort_values(by=['recall1'], ascending=False)
#add new column at start called Melody Extractor
df.insert(0, 'Processed', df.index.str.replace("Text-", "").str.replace("time-", "").str.replace("modified", "").str.replace("skyline", "").str.replace("-processed", "Processed").str.replace(r'^\s*$', "Unprocessed", regex=True))
df.insert(0, 'Melody Extractor', df.index.str.replace("Text-", "").str.replace("time-", "").str.replace("-processed", "").str.replace("modified", "Modified").str.replace("skyline", "Skyline"))
df.insert(0, 'Similarity Method', df.index.str.replace("-modified", "").str.replace("-skyline", "").str.replace("-processed", "").str.replace("time", "Time"))


df.reset_index(drop=True, inplace=True)
df.to_csv("results.csv",index=False)

# %%
df
# Out:
#   Similarity Method Melody Extractor    Processed   recall1   recall3  \
# 0              Text         Modified  Unprocessed  1.000000  1.000000
# 1              Text          Skyline  Unprocessed  1.000000  1.000000
# 2              Time         Modified  Unprocessed  0.947368  0.973684
# 3              Time          Skyline  Unprocessed  0.842105  0.947368
# 4              Text          Skyline    Processed  0.526316  0.657895
# 5              Text         Modified    Processed  0.473684  0.605263
# 6              Time         Modified    Processed  0.052632  0.078947
# 7              Time          Skyline    Processed  0.052632  0.157895
#
#     recall5  recall10   mean_rank  norm_sim    margin  avg_confidence
# 0  1.000000  1.000000    1.000000  1.000000  0.285800        0.977548
# 1  1.000000  1.000000    1.000000  1.000000  0.290936        1.000000
# 2  0.973684  1.000000    1.184211  0.999301  0.191037        0.776452
# 3  0.973684  0.973684   11.078947  0.986434  0.202716        0.784020
# 4  0.684211  0.684211  146.842105  0.880409  0.123667        0.717502
# 5  0.631579  0.657895  194.842105  0.847895  0.100749        0.676935
# 6  0.157895  0.236842  363.605263  0.721013  0.000374        0.431907
# 7  0.210526  0.236842  329.026316  0.753566  0.000266        0.431846
