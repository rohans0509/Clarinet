# %%
from mido import MidiFile

# %%
import numpy as np

# %%
file = MidiFile("test.mid",clip=True)

# %%
tracks = file.tracks

# %%
print(tracks[1][2].time)
# Out:
# 163

# %%
for e in tracks[1]:
    try:
        print(e.note)
    except:
        print("")
# Out:
# 48
# 63
# 67
# 91
# 56
# 60
# 63
# 63
# 91
# 48
# 67
# 56
# 60
# 63
# 72
# 72
# 72
# 55
# 67
# 63
# 91
# 60
# 72
# 72
# 84
# 56
# 55
# 91
# 67
# 84
# 63
# 56
# 60
# 72
# 72
# 94
# 94
# 72
# 72
# 72
# 84
# 60
# 56
# 53
# 84
# 56
# 53
# 60
# 94
# 94
# 53
# 56
# 60
# 53
# 60
# 56
# 48
# 91
# 94
# 51
# 91
# 48
# 48
# 94
# 94
# 48
# 48
# 94
# 51
# 51
# 63
# 48
# 63
# 63
# 94
# 63
# 63
# 91
# 60
# 63
# 63
# 48
# 94
# 94
# 36
# 35
# 94
# 94
# 96
# 101
# 33
# 95
# 101
# 101
# 62
# 100
# 39
# 91
# 96
# 96
# 94
# 94
# 48
# 48
# 35
# 95
# 36
# 36
# 39
# 39
# 33
# 38
# 100
# 40
# 101
# 101
# 63
# 63
# 94
# 94
# 96
# 96
# 103
# 39
# 39
# 36
# 36
# 40
# 48
# 62
# 63
# 63
# 60
# 96
# 96
# 101
# 101
# 72
# 75
# 32
# 27
# 103
# 51
# 27
# 38
# 64
# 36
# 36
# 39
# 29
# 32
# 63
# 63
# 65
# 96
# 96
# 84
# 77
# 75
# 75
# 36
# 53
# 101
# 35
# 64
# 64
# 29
# 96
# 96
# 84
# 84
# 53
# 53
# 34
# 35
# 64
# 63
# 63
# 72
# 94
# 53
# 84
# 84
# 32
# 29
# 34
# 32
# 77
# 84
# 99
# 65
# 63
# 37
# 87
# 32
# 75
# 37
# ...

# %%
file.instruments
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-e2415c948c22> in <module>
# ----> 1 file.instruments
#
# AttributeError: 'MidiFile' object has no attribute 'instruments'

# %%
print(file)
# Out:
# MidiFile(type=1, ticks_per_beat=220, tracks=[
#   MidiTrack([
#     MetaMessage('set_tempo', tempo=500000, time=0),
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('end_of_track', time=1)]),
#   MidiTrack([
#     MetaMessage('track_name', name='Acoustic Grand Piano', time=0),
#     Message('program_change', channel=0, program=0, time=0),
#     Message('note_on', channel=0, note=48, velocity=111, time=163),
#     Message('note_on', channel=0, note=63, velocity=112, time=9),
#     Message('note_on', channel=0, note=67, velocity=122, time=8),
#     Message('note_on', channel=0, note=91, velocity=124, time=115),
#     Message('note_on', channel=0, note=56, velocity=111, time=4),
#     Message('note_on', channel=0, note=60, velocity=111, time=0),
#     Message('note_on', channel=0, note=63, velocity=0, time=5),
#     Message('note_on', channel=0, note=63, velocity=114, time=0),
# ...

# %%
import miditoolkit

# %%
mid_in = miditoolkit.midi.parser.MidiFile("test.mid")

# %%
notes=mid_in.instruments[0].notes

# %%
notes[0].start
# Out:
# 172

# %%
sorted(notes,key=lambda x: x.start)
# Out:
# [Note(start=163, end=431, pitch=48, velocity=111),
#  Note(start=172, end=304, pitch=63, velocity=112),
#  Note(start=180, end=431, pitch=67, velocity=122),
#  Note(start=295, end=387, pitch=91, velocity=124),
#  Note(start=299, end=497, pitch=56, velocity=111),
#  Note(start=299, end=524, pitch=60, velocity=111),
#  Note(start=304, end=524, pitch=63, velocity=114),
#  Note(start=524, end=607, pitch=72, velocity=120),
#  Note(start=607, end=704, pitch=72, velocity=120),
#  Note(start=682, end=761, pitch=55, velocity=123),
#  Note(start=695, end=840, pitch=67, velocity=124),
#  Note(start=700, end=805, pitch=91, velocity=124),
#  Note(start=700, end=880, pitch=63, velocity=116),
#  Note(start=704, end=911, pitch=60, velocity=113),
#  Note(start=704, end=915, pitch=72, velocity=121),
#  Note(start=708, end=876, pitch=84, velocity=123),
#  Note(start=722, end=884, pitch=56, velocity=120),
#  Note(start=915, end=1197, pitch=72, velocity=119),
# ...
