# %%
import pandas as pd

# %%
df = pd.read_csv("maestro-v3.0.0.csv")

# %%
df = df[df['year'] == 2018]

# %%
midi_names = df['midi_filename']

# %%
melody_names = [n.replace(".midi", "-melody.midi") for n in midi_names]
melody_names = [n.replace("2018","2018-melody") for n in melody_names]

# %%
df['melody_filename'] = melody_names
# Out:
# c:\users\kshitij alwadhi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#            canonical_composer                              canonical_title  \
# 0                  Alban Berg                                 Sonata Op. 1
# 18         Alexander Scriabin        Sonata No. 2 in G-sharp Minor, Op. 19
# 19         Alexander Scriabin        Sonata No. 2 in G-sharp Minor, Op. 19
# 21         Alexander Scriabin        Sonata No. 3 in F-sharp Minor, Op. 23
# 22         Alexander Scriabin        Sonata No. 3 in F-sharp Minor, Op. 23
# ...                       ...                                          ...
# 1224      Sergei Rachmaninoff             Preludes Op. 23, Nos. 2, 4 and 5
# 1240  Wolfgang Amadeus Mozart  Nine variations on a minuet by Duport, K537
# 1253  Wolfgang Amadeus Mozart                    Sonata in C Minor, K. 457
# 1255  Wolfgang Amadeus Mozart                       Sonata in D Major K576
# 1274  Wolfgang Amadeus Mozart                 Sonata in F Major, K533/K494
#
# ...

# %%
df.to_csv("metadata.csv",index=False)
